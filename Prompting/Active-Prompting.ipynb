# %% [markdown]
# # Import openai library

# %%
# !pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.1 MB/s eta 0:00:00
# ...

# %%
# !git clone -q https://github.com/shizhediao/active-prompt.git

# %%
# %cd active-prompt
# Out:
# /content/active-prompt

# %%
# !gdown 1JpcJGLzldooWLCe2gPtlAlvRVXmwra8n
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1JpcJGLzldooWLCe2gPtlAlvRVXmwra8n
# To: /content/active-prompt/QA_test.json
# 100% 26.3k/26.3k [00:00<00:00, 32.2MB/s]

# %% [markdown]
# # Init conversation

# %%
# Go to active-prompting/utils.py to change the api-key
OPENAI_API_KEY = "YOUR_API_KEY"

# %%
import json
import random

n_sample = 10
data = json.load(open('QA_test.json', 'r'))
data = random.sample(data, n_sample)

with open('dataset/GSM8K/test.jsonl', 'w') as f:
    for sample in data:
      f.write('{' + fr'"question":"{sample["question"]}", "answer":"{sample["answer"]}\n#### {sample["final"]}"' + '}\n')

# %%
# !python inference.py --dataset="gsm8k" --model="gpt-3.5-turbo" --method="active_cot" --qes_limit=10 --prompt_path="./inference_prompts/gsm8k_k=10" --random_seed=42 --multipath=1 --temperature=0.7 --api_time_interval=2
# Out:
# Temperature: 0
# *****************************
# Namespace(random_seed=42, dataset='gsm8k', prompt_path='./inference_prompts/gsm8k_k=10', model='gpt-3.5-turbo', method='active_cot', output_dir='./results/', max_length_cot=256, qes_limit=10, api_time_interval=2.0, temperature=0, multipath=1, concat_length=4, use_code_style_prompt=False, basic_cot=False, dataset_path='./dataset/GSM8K/test.jsonl', direct_answer_trigger='\nTherefore, the answer (arabic numerals) is', direct_answer_trigger_for_zeroshot='The answer (arabic numerals) is', direct_answer_trigger_for_zeroshot_cot='\nTherefore, the answer (arabic numerals) is', direct_answer_trigger_for_fewshot='The answer is', cot_trigger="Let's think step by step.")
# *****************************
# API_KEY: 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
# dataset: gsm8k
# dataset_size: 10
# dataloader size: 10
# Inference Start
# --------------------
# Question number: 0
# Dataset index: 7
# ...
